# %%
import os
import numpy as np
import pandas as pd
import tqdm
from joblib import Parallel, delayed

# %%
save_dir = './processed_data'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
root_dir = r'source_data'
filepath = os.path.join(root_dir, r'skempi_v2.csv')
assert os.path.exists(filepath), f'{filepath} not exists!'
df = pd.read_csv(filepath, sep=";", na_values=['n.b'])
print(f"df.shape: {df.shape}")
display(df.head())
# Out:
# df.shape: (7085, 29)
#        #Pdb Mutation(s)_PDB Mutation(s)_cleaned iMutation_Location(s)  \
# 0  1CSE_E_I           LI45G               LI38G                   COR
# 1  1CSE_E_I           LI45S               LI38S                   COR
# 2  1CSE_E_I           LI45P               LI38P                   COR
# 3  1CSE_E_I           LI45I               LI38I                   COR
# 4  1CSE_E_I           LI45D               LI38D                   COR
#
#   Hold_out_type Hold_out_proteins Affinity_mut (M)  Affinity_mut_parsed  \
# 0         Pr/PI             Pr/PI         5.26E-11         5.260000e-11
# 1         Pr/PI             Pr/PI         8.33E-12         8.330000e-12
# 2         Pr/PI             Pr/PI         1.02E-07         1.020000e-07
# 3         Pr/PI             Pr/PI         1.72E-10         1.720000e-10
# 4         Pr/PI             Pr/PI         1.92E-09         1.920000e-09
#
#   Affinity_wt (M)  Affinity_wt_parsed  ... koff_mut_parsed koff_wt (s^(-1))  \
# 0        1.12E-12        1.120000e-12  ...             NaN              NaN
# 1        1.12E-12        1.120000e-12  ...             NaN              NaN
# 2        1.12E-12        1.120000e-12  ...             NaN              NaN
# 3        1.12E-12        1.120000e-12  ...             NaN              NaN
# 4        1.12E-12        1.120000e-12  ...             NaN              NaN
#
#   koff_wt_parsed dH_mut (kcal mol^(-1))  dH_wt (kcal mol^(-1))  \
# 0            NaN                    NaN                    NaN
# 1            NaN                    NaN                    NaN
# 2            NaN                    NaN                    NaN
# 3            NaN                    NaN                    NaN
# 4            NaN                    NaN                    NaN
#
#    dS_mut (cal mol^(-1) K^(-1))  dS_wt (cal mol^(-1) K^(-1))  Notes Method  \
# 0                           NaN                          NaN    NaN   IASP
# 1                           NaN                          NaN    NaN   IASP
# 2                           NaN                          NaN    NaN   IASP
# 3                           NaN                          NaN    NaN   IASP
# 4                           NaN                          NaN    NaN   IASP
#
#    SKEMPI version
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
#
# [5 rows x 29 columns]

# %%
df['Source Data Set'] = 'SKEMPI v2.0'

df.rename(columns={
    '#Pdb': 'PDB',
#     'Mutation(s)_cleaned': 'Mutations',
#     'Mutation(s)_PDB': 'Mutations',
    'Affinity_mut_parsed': 'KD(M)',
    'Protein 1': 'Ligand Name', 
    'Protein 2': 'Receptor Name',
    'Temperature': 'Temperature(K)',
    'Reference': 'Affinity PubMed ID',
    'Method': 'Affinity Method',
},inplace=True)

# 添加WT
df_WT = df.groupby(by='PDB').apply(lambda x: x.iloc[0])
# df_WT['Mutations'] = ''
df_WT['Mutation(s)_cleaned'] = ''
df_WT['Mutation(s)_PDB'] = ''
df_WT['KD(M)'] = df_WT['Affinity_wt_parsed']
df_WT['Affinity_mut (M)'] = np.nan
df_WT.reset_index(drop=True,inplace=True)
print(f"df_WT.shape: {df_WT.shape}")
df = pd.concat((df_WT,df), axis=0, ignore_index=True)


# 添加chain id, mutations, PDB...
df.loc[:,['Model','Affinity Release Date','Resolution(Å)']] = np.nan
df['Ligand Chains'] = df['PDB'].apply(lambda x: ','.join([c for c in x.split('_')[1]]))
df['Receptor Chains'] = df['PDB'].apply(lambda x: ','.join([c for c in x.split('_')[2]]))
df['PDB'] = df['PDB'].apply(lambda x: x[:4])
df['Mutation(s)_cleaned'] = df['Mutation(s)_cleaned'].apply( lambda x: ', '.join([f'{mut[1]}_{mut[0]}{mut[2:]}' for mut in x.split(',') if mut!='']) )
df['Mutation(s)_PDB'] = df['Mutation(s)_PDB'].apply( lambda x: ', '.join([f'{mut[1]}_{mut[0]}{mut[2:]}' for mut in x.split(',') if mut!='']) )
print(f"df.shape: {df.shape}")

print(f"Number of unique PDBs in df: {len(set(df['PDB'].tolist()))}")
# Out:
# df_WT.shape: (348, 30)
# df.shape: (7433, 35)
# Number of unique PDBs in df: 345

# %% [markdown]
# # Manually fix errors

# %%
# SKEMPI v2.0的5E9D的标注错误,原标为A,B_C,D,E,应该改为A,B,C_D,E。
ind = df[df['PDB']=='5E9D'].index
df.loc[ind,'Ligand Chains'] = 'A,B,C'
df.loc[ind,'Receptor Chains'] = 'D,E'

# %% [markdown]
# # Screening

# %% [markdown]
# ## Screen out those without affinity labels

# %%
df_delphase1 = df[df['KD(M)'].isna()]
df_delphase1.insert(loc=0,column='Reason for Deletion',value=np.nan)
df_delphase1['Reason for Deletion'] = 'without affinity labels'
df = df[~df['KD(M)'].isna()]

pdbs_drop = set(df_delphase1['PDB'].values.tolist())
print(f"Deleted {len(df_delphase1)} records with {len(pdbs_drop)} unique PDBs in screening phase1 due to 'without affinity labels', they are:\n{pdbs_drop}")
# Out:
# Deleted 287 records with 73 unique PDBs in screening phase1 due to 'without affinity labels', they are:
# {'2WPT', '1FSS', '1DVF', '3G6D', '2B2X', '4Y61', '4UYQ', '4YEB', '2AK4', '5F4E', '3HFM', '4CPA', '1QAB', '3UIG', '4UYP', '4O27', '3BE1', '4E6K', '2AJF', '1N8Z', '4YFD', '1BD2', '4N8V', '4JFF', '3HG1', '2J0T', '1JCK', '1GC1', '4FZA', '3KBH', '3QDG', '1AO7', '4JFE', '4J2L', '4NKQ', '3NVN', '3AAA', '3W2D', '4K71', '2KSO', '4RS1', '1IAR', '1QRN', '3BIW', '4NZW', '2REX', '4JPK', '4JFD', '5M2O', '1GRN', '3QDJ', '5DWU', '5K39', '4ZS6', '4B0M', '1VFB', '2C0L', '4U6H', '3M62', '3SF4', '2DVW', '2HRK', '1B41', '4MNQ', '1YCS', '5C6T', '3NVQ', '4BFI', '1SBB', '1MHP', '3BDY', '1QSF', '4YH7'}
# /tmp/ipykernel_585813/2257438576.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_delphase1['Reason for Deletion'] = 'without affinity labels'

# %% [markdown]
# ## Screening out samples that are not Protein-Protein-Complex

# %%
# ** SKEMPI v2.0数据集全是蛋白蛋白复合体，因此不许执行这一步筛选。 **

# # 精筛：筛除受体链、配体链不是氨基酸链的样本
# df.reset_index(inplace=True, drop=True)

# from utils import check_chains
# assert len(set(df.index.values.tolist())) == len(df)
# # data_dir = r"E:\1.THPRD\1.AI_LifeScience\3.AntiBody\我们的创新\1.RDE-PPdG\参考文献\公开数据集\SKEMPI v2.0\SKEMPI2_PDBs\PDBs" 
# data_dir = r"./source_data/SKEMPI v2.0/PDBs" 
# keep_inds = []
# for pdb in tqdm.tqdm(set(df.PDB.tolist()),'Iterate over all PDBs'):
#     pdb_file = os.path.join( data_dir, f'{pdb.upper()}.pdb' )
#     df_tmp = df[df['PDB']==pdb]
#     for ind in df_tmp.index:
#         ligand_chains = [chain.strip() for chain in df_tmp.loc[ind,'Ligand Chains'].split(',')]
#         receptor_chains = [chain.strip() for chain in df_tmp.loc[ind,'Receptor Chains'].split(',')]
#         result = check_chains(pdb_file, ligand_chains, receptor_chains)
#         if all(result.values()):
#             keep_inds.append(ind)
#         else:
#             print(f"Delete {pdb}, because: {result}")
# drop_inds = [ind for ind in df.index.tolist() if ind not in keep_inds]
# df_delphase2 = df.loc[drop_inds]
# df_delphase2['Reason for Deletion'] = 'not Protein-Protein-Complex'

# pdbs_drop = set(df_drop['PDB'].values.tolist())
# print(f'Number of dropped PDBs: {len(pdbs_drop)}, which is:\n{pdbs_drop}')
# df = df.loc[keep_inds]
# print('After the filtering, we get df:')
# display(df)

# %% [markdown]
# ## save deleted samples as an excel file

# %%
# save as excel file
df_del = df_delphase1# pd.concat( [df_delphase1, df_delphase2], axis=0 )
df_del.to_excel( os.path.join(save_dir,'SKEMPI v2.0(samples_deleted).xlsx') )

# %% [markdown]
# # PDB info

# %%
# # 串行版
# from utils import get_pdb_info
# pdbs = set(df['PDB'].values)
# for pdb in tqdm.tqdm_notebook(pdbs):
#     results = get_pdb_info(pdb)
#     if results['Resolution']!=None:
#         df.loc[df[df.PDB==pdb].index,'Resolution(Å)'] = results['Resolution'].replace('Å','').strip()
#     if results['Method'] != None:
#         df.loc[df[df.PDB==pdb].index,'Structure Method'] = results['Method']
#     if results['Release Date'] != None:
#         df.loc[df[df.PDB==pdb].index,'PDB Release Date'] = results['Release Date']
#     # 这是PDB的PubMed ID, 不是亲和力的PubMed ID
#     if results['PubMed ID'] != None:
#         df.loc[df[df.PDB==pdb].index,'PDB PubMed ID'] = results['PubMed ID']

        
        
# 并行版
from utils import get_pdb_info

df['PDB PubMed ID'] = np.nan
pdbs = set(df.loc[df['PDB PubMed ID'].isna(), 'PDB'].values.tolist())
N = len(pdbs)
try_times = 0
while N>0 and try_times<20:
    # 获取pdb信息
    infos = Parallel(n_jobs=-1)(delayed(get_pdb_info)(pdb) for pdb in tqdm.tqdm(pdbs,desc=f'Fetching PDB infomation of {len(pdbs)} PDBs...'))
    infos = dict([(info['PDB'], info) for info in infos])
    # 填写到df中
    for pdb in tqdm.tqdm(pdbs,desc="Fill in the PDB infomations..."):
        info = infos[pdb]
        if info['Resolution']!=None:
            df.loc[df[df.PDB==pdb].index,'Resolution(Å)'] = info['Resolution'].replace('Å','').strip()
        if info['Method'] != None:
            df.loc[df[df.PDB==pdb].index,'Structure Method'] = info['Method']
        if info['Release Date'] != None:
            df.loc[df[df.PDB==pdb].index,'PDB Release Date'] = info['Release Date']   
        # 注意：这是PDB的PubMed ID, 不是亲和力的PubMed ID
        if info['PubMed ID'] != None:
            df.loc[df[df.PDB==pdb].index,'PDB PubMed ID'] = info['PubMed ID']
            
    try_times += 1
    pdbs = set(df.loc[df['PDB PubMed ID'].isna(), 'PDB'].values.tolist())
    N = len(pdbs)

N_notfound = df['PDB PubMed ID'].isna().sum()
if N_notfound==0:
    print(f">>> 成功找到所有Affinity PubMed ID的Release Date！")
else:
    print(f">>> 还有{N_notfound}个record的Release Date没找到。他们的Affinity PubMed ID是：{set(df.loc[df['Resolution(Å)'].isna(),'PDB'].values.tolist())}")
# Out:
# Fetching PDB infomation of 345 PDBs...: 100%|██████████| 345/345 [00:08<00:00, 38.79it/s]
# Fill in the PDB infomations...: 100%|██████████| 345/345 [00:02<00:00, 125.70it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 4791.36it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 132.10it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 6325.72it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 121.99it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 6762.58it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 125.90it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 6355.54it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 124.86it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 6918.12it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 130.70it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 7109.66it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 121.84it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 6237.91it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 124.01it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 6220.44it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 130.64it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 6071.37it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 124.56it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 8865.37it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 121.25it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 6322.54it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 121.67it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 6378.09it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 141.83it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 6239.46it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 119.21it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 10570.91it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 123.45it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 6365.19it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 121.94it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 12568.25it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 120.14it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 12177.01it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 123.69it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 5844.81it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 121.97it/s]
# Fetching PDB infomation of 18 PDBs...: 100%|██████████| 18/18 [00:00<00:00, 7281.78it/s]
# Fill in the PDB infomations...: 100%|██████████| 18/18 [00:00<00:00, 125.21it/s]
# >>> 还有65个record的Release Date没找到。他们的Affinity PubMed ID是：{'1KBH', '2KSO'}

# %% [markdown]
# # affinity info

# %%
# # 根据Affinity PubMed ID查询Affinity Release Date
# from utils import get_pubdate
# for pubmed_id in tqdm.tqdm_notebook(set(df['Affinity PubMed ID'].values)):
#     try:
#         pubdate = get_pubdate(str(pubmed_id), dst_datetime_format='%Y-%m-%d')
#         df.loc[df[df['Affinity PubMed ID']==pubmed_id].index, 'Affinity Release Date' ] = pubdate
#     except:
#         print(f"Cound not fetch pubdate for pubmed_id=='{pubmed_id}'")
        
        
        
# 根据Affinity PubMed ID查询Affinity Release Date
# 并行版：
from utils import get_pubdate
df['Affinity Release Date'] = np.nan
PMIDs = set(df.loc[~df['Affinity PubMed ID'].isna() * df['Affinity Release Date'].isna(), 'Affinity PubMed ID'].values.tolist())
N = len(PMIDs)
try_times = 0
while N>0 and try_times<20:
    # 获取pdb信息
    pubdate_infos = Parallel(n_jobs=8)(delayed(get_pubdate)(PMID) for PMID in tqdm.tqdm(PMIDs,desc=f'Fetching affinity release datas of {len(PMIDs)} papers...'))
    # 填写到df中
    for pubdate_info in tqdm.tqdm(pubdate_infos,desc="Fill in affinity release dates..."):
        PMID, pubdate = pubdate_info['PMID'], pubdate_info['publish date']
        # 是亲和力的PubMed ID
        df.loc[df['Affinity PubMed ID']==PMID, 'Affinity Release Date'] = pubdate
    
    PMIDs = set(df.loc[~df['Affinity PubMed ID'].isna() * df['Affinity Release Date'].isna(), 'Affinity PubMed ID'].values.tolist())
    N = len(PMIDs)
    try_times += 1
    
N_notfound = df['Affinity Release Date'].isna().sum() - df['Affinity PubMed ID'].isna().sum()
if N_notfound==0:
    print(f">>> 成功找到所有Affinity PubMed ID的Release Date！")
else:
    tmp_pmids = set(df.loc[df['Affinity Release Date'].isna(),'Affinity PubMed ID'].values.tolist())
    print(f">>> 还有{N_notfound}个record的亲和力Release Date没找到。他们属于{len(tmp_pmids)}篇不同的paper,分别是：")
    print('\n'.join(tmp_pmids))
# Out:
# Fetching affinity release datas of 295 papers...: 100%|██████████| 295/295 [00:55<00:00,  5.32it/s]
# Fill in affinity release dates...: 100%|██████████| 295/295 [00:00<00:00, 653.93it/s]
# Fetching affinity release datas of 147 papers...: 100%|██████████| 147/147 [00:25<00:00,  5.77it/s]
# Fill in affinity release dates...: 100%|██████████| 147/147 [00:00<00:00, 658.77it/s]
# Fetching affinity release datas of 73 papers...: 100%|██████████| 73/73 [00:11<00:00,  6.43it/s]
# Fill in affinity release dates...: 100%|██████████| 73/73 [00:00<00:00, 563.02it/s]
# Fetching affinity release datas of 37 papers...: 100%|██████████| 37/37 [00:03<00:00, 10.34it/s]
# Fill in affinity release dates...: 100%|██████████| 37/37 [00:00<00:00, 525.40it/s]
# Fetching affinity release datas of 20 papers...: 100%|██████████| 20/20 [00:01<00:00, 18.75it/s]
# Fill in affinity release dates...: 100%|██████████| 20/20 [00:00<00:00, 513.59it/s]
# Fetching affinity release datas of 9 papers...: 100%|██████████| 9/9 [00:00<00:00, 4205.05it/s]
# Fill in affinity release dates...: 100%|██████████| 9/9 [00:00<00:00, 468.28it/s]
# Fetching affinity release datas of 4 papers...: 100%|██████████| 4/4 [00:00<00:00, 2561.80it/s]
# Fill in affinity release dates...: 100%|██████████| 4/4 [00:00<00:00, 323.85it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 1685.14it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 231.58it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 1455.34it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 230.99it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 1391.15it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 130.90it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 927.43it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 219.41it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 854.15it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 225.99it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 1386.55it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 225.63it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 1417.23it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 244.64it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 1381.30it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 226.71it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 710.54it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 255.55it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 2225.09it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 220.92it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 954.88it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 286.41it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 988.41it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 216.70it/s]
# Fetching affinity release datas of 2 papers...: 100%|██████████| 2/2 [00:00<00:00, 706.71it/s]
# Fill in affinity release dates...: 100%|██████████| 2/2 [00:00<00:00, 312.20it/s]
# >>> 还有338个record的亲和力Release Date没找到。他们属于2篇不同的paper,分别是：
# Stephen Ming-teh Lu, PhD Thesis, Purdue University, 2000
# Water-mediated interaction at a protein-protein interface, Chemical Physics, Volume 307, Issues 2-3, 2004

# %% [markdown]
# # save

# %%
df.reset_index(drop=True, inplace=True)
df = df.loc[:,[
    'PDB', 'Source Data Set', 'Model', 'Mutation(s)_cleaned', 'Mutation(s)_PDB', 'Ligand Chains', 'Receptor Chains', 'Ligand Name', 'Receptor Name', 
    'KD(M)', 'Affinity Method', 'Structure Method', 'Temperature(K)', 'Resolution(Å)', 
    'PDB PubMed ID', 'PDB Release Date', 'Affinity PubMed ID', 'Affinity Release Date', 
]]
display(df)
df.to_excel(os.path.join(save_dir,'SKEMPI v2.0.xlsx'))
# Out:
#        PDB Source Data Set  Model Mutation(s)_cleaned Mutation(s)_PDB  \
# 0     1A22     SKEMPI v2.0    NaN
# 1     1A4Y     SKEMPI v2.0    NaN
# 2     1ACB     SKEMPI v2.0    NaN
# 3     1AHW     SKEMPI v2.0    NaN
# 4     1AK4     SKEMPI v2.0    NaN
# ...    ...             ...    ...                 ...             ...
# 7141  3QIB     SKEMPI v2.0    NaN               P_K8R           P_K9R
# 7142  3QIB     SKEMPI v2.0    NaN              P_T11A          P_T12A
# 7143  3QIB     SKEMPI v2.0    NaN              P_T11S          P_T12S
# 7144  3QIB     SKEMPI v2.0    NaN              P_T11N          P_T12N
# 7145  3QIB     SKEMPI v2.0    NaN       P_Y6F, P_T11S   P_Y7F, P_T12S
#
#      Ligand Chains Receptor Chains                Ligand Name  \
# 0                A               B       Human growth hormone
# 1                A               B     Ribonuclease inhibitor
# 2                E               I  Bovine alpha-chymotrypsin
# 3              A,B               C     Immunoglobulin fab 5G9
# 4                A               D              Cyclophilin A
# ...            ...             ...                        ...
# 7141         A,B,P             C,D      I-Ek plus MCC peptide
# 7142         A,B,P             C,D      I-Ek plus MCC peptide
# 7143         A,B,P             C,D      I-Ek plus MCC peptide
# 7144         A,B,P             C,D      I-Ek plus MCC peptide
# 7145         A,B,P             C,D      I-Ek plus MCC peptide
#
#              Receptor Name         KD(M) Affinity Method   Structure Method  \
# 0      hGH binding protein  9.000000e-10             SPR  X-RAY DIFFRACTION
# 1               Angiogenin  5.000000e-16            SFPF  X-RAY DIFFRACTION
# 2                  Eglin c  1.490000e-12            IASP  X-RAY DIFFRACTION
# 3            Tissue factor  3.400000e-09            IASP  X-RAY DIFFRACTION
# 4     HIV-1 capsid protein  1.200000e-05             SPR  X-RAY DIFFRACTION
# ...                    ...           ...             ...                ...
# 7141               2B4 TCR  2.400000e-04             SPR  X-RAY DIFFRACTION
# 7142               2B4 TCR  1.100000e-03             SPR  X-RAY DIFFRACTION
# 7143               2B4 TCR  3.380000e-05             SPR  X-RAY DIFFRACTION
# 7144               2B4 TCR  4.340000e-05             SPR  X-RAY DIFFRACTION
# 7145               2B4 TCR  4.290000e-05             SPR  X-RAY DIFFRACTION
#
#      Temperature(K) Resolution(Å) PDB PubMed ID PDB Release Date  \
# 0               298          2.60       9571026       1998-04-29
# 1               298          2.00       9311977       1998-10-14
# 2               294          2.00       1583684       1993-10-31
# 3      298(assumed)          3.00       9480775       1998-02-25
# 4      298(assumed)          2.36       8980234       1997-10-15
# ...             ...           ...           ...              ...
# 7141            298          2.70      21490152       2011-04-27
# 7142            298          2.70      21490152       2011-04-27
# 7143            298          2.70      21490152       2011-04-27
# 7144            298          2.70      21490152       2011-04-27
# 7145            298          2.70      21490152       2011-04-27
#
#      Affinity PubMed ID Affinity Release Date
# 0               7504735            1993 Dec 5
# 1               9050852            1997 Mar 4
# 2               9048543           1997 Feb 18
# 3               9480775            1998 Feb 6
# 4               9223641           1997 Jun 27
# ...                 ...                   ...
# 7141           12152083            2002 Aug 1
# 7142           12152083            2002 Aug 1
# 7143           12152083            2002 Aug 1
# 7144           12152083            2002 Aug 1
# 7145           12152083            2002 Aug 1
#
# [7146 rows x 18 columns]

# %%
df['Affinity Method'].value_counts()
# Out:
# Affinity Method
# SPR         2660
# FL          1460
# ITC          584
# IASP         518
# SFFL         365
# RA           339
# SP           339
# ELISA        220
# IAFL         189
# KinExA       134
# IARA         133
# BI            59
# CSPRIA        45
# ELFA          26
# ESMA          23
# SE            14
# SFPF          12
# SPR,SFFL      10
# IAGE           9
# EMSA           7
# Name: count, dtype: int64
