# %%
import pandas as pd
import numpy as np
import tqdm

# %%
import os
save_dir = './processed_data'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
root_dir = r"./source_data"
filepath = os.path.join(root_dir, r"sabdab_summary_all-by20240725.xlsx")
if not os.path.exists(filepath.replace('.tsv','.xlsx')):
    assert os.path.exists(filepath), f'{filepath} not exists!'
    df = pd.read_csv(filepath, sep='\t', dtype={'pmid':str})
    df.to_excel(filepath.replace('.tsv','.xlsx'))
else:
    df = pd.read_excel(filepath.replace('.tsv','.xlsx'), dtype={'pmid':str}, index_col=0)
display(df)
# Out:
#         pdb Hchain Lchain  model antigen_chain       antigen_type  \
# 0      8udz      C      D      0             B            protein
# 1      8udz      E      F      0         B | A  protein | protein
# 2      8vyl      F    NaN      0         D | C  protein | protein
# 3      8vyl      E    NaN      0         B | A  protein | protein
# 4      8q5y      R      L      0             D            protein
# ...     ...    ...    ...    ...           ...                ...
# 17270  6ejm      H      h      0             B            protein
# 17271  7lo6      J      I      0             C            protein
# 17272  3vi3      H      L      0             D            protein
# 17273  6zdg      F      G      0             D            protein
# 17274  5bk0      B      A      0             E            peptide
#
#       antigen_het_name                                       antigen_name  \
# 0                  NaN       transforming growth factor beta-1 proprotein
# 1              NA | NA  transforming growth factor beta-1 proprotein |...
# 2              NA | NA  hemoglobin subunit beta | hemoglobin subunit a...
# 3              NA | NA  hemoglobin subunit beta | hemoglobin subunit a...
# 4                  NaN                                 spike glycoprotein
# ...                ...                                                ...
# 17270              NaN                                       cd81 antigen
# 17271              NaN        envelope glycoprotein bg505 sosip.664 gp120
# 17272              NaN                                    integrin beta-1
# 17273              NaN                                 spike glycoprotein
# 17274              NaN                circumsporozoite protein nanp 5-mer
#
#                           short_header      date  ...   scfv engineered  \
# 0      SIGNALING PROTEIN/IMMUNE SYSTEM  07/17/24  ...  False       True
# 1      SIGNALING PROTEIN/IMMUNE SYSTEM  07/17/24  ...  False       True
# 2                     OXYGEN TRANSPORT  07/17/24  ...  False       True
# 3                     OXYGEN TRANSPORT  07/17/24  ...  False       True
# 4                        VIRAL PROTEIN  07/17/24  ...  False       True
# ...                                ...       ...  ...    ...        ...
# 17270                    CELL ADHESION  09/22/17  ...   True       True
# 17271      VIRAL PROTEIN/IMMUNE SYSTEM  02/09/21  ...  False       True
# 17272      CELL ADHESION/IMMUNE SYSTEM  09/21/11  ...  False       True
# 17273                    VIRAL PROTEIN  06/14/20  ...  False       True
# 17274                    IMMUNE SYSTEM  09/12/17  ...  False       True
#
#       heavy_subclass light_subclass light_ctype      affinity    delta_g  \
# 0              IGHV3          IGLV6      Lambda           NaN        NaN
# 1              IGHV3          IGLV6      Lambda           NaN        NaN
# 2              IGHV1            NaN         NaN           NaN        NaN
# 3              IGHV1            NaN         NaN           NaN        NaN
# 4              IGHV3          IGKV1       Kappa           NaN        NaN
# ...              ...            ...         ...           ...        ...
# 17270        unknown        unknown     unknown  8.600000e-10 -12.367557
# 17271          IGHV1          IGKV3       Kappa           NaN        NaN
# 17272          IGHV1          IGKV2       Kappa           NaN        NaN
# 17273          IGHV3          IGKV1       Kappa           NaN        NaN
# 17274          IGHV3          IGKV2       Kappa           NaN        NaN
#
#       affinity_method temperature pmid
# 0                 NaN         NaN  NaN
# 1                 NaN         NaN  NaN
# 2                 NaN         NaN  NaN
# 3                 NaN         NaN  NaN
# 4                 NaN         NaN  NaN
# ...               ...         ...  ...
# 17270             SPR         NaN  TBD
# 17271             NaN         NaN  NaN
# 17272             NaN         NaN  NaN
# 17273             NaN         NaN  NaN
# 17274             NaN         NaN  NaN
#
# [17275 rows x 30 columns]

# %% [markdown]
# # Screening

# %% [markdown]
# ## Affinity label

# %%
assert len(df[df['affinity'].isna() * ~df['delta_g'].isna()]) == 0

# %%
# 没有记录亲和力的
df_delphase1 = df[df['affinity'].isna()]
df_delphase1.insert(loc=0,column='Reason for Deletion', value='no affinity label')

# 记录了亲和力的
df = df[~df['affinity'].isna()]

# %% [markdown]
# ## Protein Protein Complex

# %%
# 初筛：删除抗原不是氨基酸链的样本
del_flags = df['antigen_type'].apply(
    lambda x: x in [
        'Hapten', 'carbohydrate', 'carbohydrate | protein', 'carbohydrate | protein | protein',
        'nucleic-acid', 'nucleic-acid | nucleic-acid', 'nucleic-acid | nucleic-acid | nucleic-acid', 'protein | nucleic-acid'])
df_delphase2 = df[del_flags]
df_delphase2.insert(loc=0,column='Reason for Deletion',value=np.nan)
df_delphase2.loc[:,'Reason for Deletion'] = 'not Protein-Protein-Complex'

df = df[~del_flags]

# %% [markdown]
# ## no antigen chain

# %%
df_delphase3 = df[df['antigen_chain'].isna()]
df_delphase3.insert(loc=0,column='Reason for Deletion',value='no antigen chain')

df = df[~df['antigen_chain'].isna()]

# %%
# 少量样本仅有H链（或L链），且antigen_chain也是H链（或L链），删除这类样本
df_delphase4 = df[ ((df['antigen_chain']==df['Lchain'])*df['Hchain'].isna()) | ((df['antigen_chain']==df['Hchain'])*df['Lchain'].isna()) ]
df_delphase4.insert(loc=0,column='Reason for Deletion',value='no antigen chain')

df = df.drop(index=df_delphase4.index)

# %% [markdown]
# ## manually delete records with chain annotation error

# %%
# # 手动删除错误样本
del_pdbs = ['5j74', '1h8s', '1zea', '3gm0', '3gkz', '4gqp', '5j74', '6df1']
df_delphase5 = df.loc[ df['pdb'].apply(lambda x: x in del_pdbs), : ]
df_delphase5.insert(loc=0,column='Reason for Deletion',value='chain annotation error')

df = df[ df['pdb'].apply(lambda x: x not in del_pdbs) ]

# %% [markdown]
# ## save deleted samples as an excel file

# %%
df_del = pd.concat([df_delphase1,df_delphase2,df_delphase3,df_delphase4,df_delphase5], axis=0)
df_del.to_excel( os.path.join(save_dir,'SAbDab(samples_deleted).xlsx') )

# %% [markdown]
# # rename columns

# %%
df.rename(columns={
    'pdb': 'PDB', 
    'antigen_chain': 'Receptor Chains', 
    'affinity': 'KD(M)', 
    'affinity_method': 'Affinity Method',
    'temperature': 'Temperature(K)',
    'antigen_name': 'Receptor Name',
    'resolution': 'Resolution(Å)',
    'pmid': 'Affinity PubMed ID',
    'date': 'Affinity Release Date',
    'model': 'Model',
},inplace=True)

df['Receptor Chains'] = df['Receptor Chains'].apply(lambda x: x.split(' | '))
df['Hchain'].fillna(value='', inplace=True)
df['Lchain'].fillna(value='', inplace=True)
assert set(df.loc[:,'Hchain'].apply(lambda x: len(x)).tolist())=={0,1}
assert set(df.loc[:,'Lchain'].apply(lambda x: len(x)).tolist())=={0,1}
for ind in df.index:
    df.loc[ind,'Ligand Chains'] = ', '.join( [chain for chain in df.loc[ind,['Hchain','Lchain']] if chain!=''] )                                                                    
df['Receptor Chains'] = df['Receptor Chains'].apply(lambda x: ', '.join(x))                                                                       

df.drop(columns=['Hchain','Lchain'], inplace=True)

df['Affinity PubMed ID'] = df['Affinity PubMed ID'].astype(str)
df.loc[:,'Mutations'] = np.nan
df.loc[:,'PDB'] = df['PDB'].apply(lambda x: x.upper())
df.loc[:,'Temperature(K)'].fillna(value='None',inplace=True)
df.loc[:,'Temperature(K)'] = df.loc[:,'Temperature(K)'].apply(lambda x:np.nan if x=='None' else 273.15+float(x))
df.loc[:,'Ligand Name'] = 'antibody'
df.loc[:, 'Source Data Set'] = 'SAbDab'
df
# Out:
#         PDB  Model Receptor Chains antigen_type antigen_het_name  \
# 4880   6FE4      0               A      protein              NaN
# 4887   5W08      0               C      protein              NaN
# 4901   2NY3      0               A      protein              NaN
# 4905   6H7O      0               B      protein              NaN
# 4911   1NCA      0               N      protein              NaN
# ...     ...    ...             ...          ...              ...
# 17242  3IDX      0               G      protein              NaN
# 17253  4PS4      0               A      protein              NaN
# 17257  5KVD      0               E      protein              NaN
# 17258  2X89      0               F      protein              NaN
# 17270  6EJM      0               B      protein              NaN
#
#                               Receptor Name                 short_header  \
# 4880           shiga-like toxin 2 subunit b                        TOXIN
# 4887                      hemagglutinin ha1  VIRAL PROTEIN/IMMUNE SYSTEM
# 4901            envelope glycoprotein gp120  VIRAL PROTEIN/IMMUNE SYSTEM
# 4905             beta-1 adrenergic receptor           ELECTRON TRANSPORT
# 4911   influenza a subtype n9 neuraminidase        HYDROLASE(O-GLYCOSYL)
# ...                                     ...                          ...
# 17242                hiv-1 hxbc2 gp120 core                IMMUNE SYSTEM
# 17253                        interleukin-13                IMMUNE SYSTEM
# 17257                    zika envelope diii  VIRAL PROTEIN/IMMUNE SYSTEM
# 17258                  beta-2-microglobulin                IMMUNE SYSTEM
# 17270                          cd81 antigen                CELL ADHESION
#
#       Affinity Release Date  \
# 4880               12/29/17
# 4887               05/30/17
# 4901               11/20/06
# 4905               07/31/18
# 4911               01/21/92
# ...                     ...
# 17242              07/22/09
# 17253              03/06/14
# 17257              07/14/16
# 17258              03/07/10
# 17270              09/22/17
#
#                                                 compound  \
# 4880   Crystal structure of the complex between Shiga...
# 4887   A/Texas/50/2012(H3N2) Influenza hemagglutinin ...
# 4901   HIV-1 gp120 Envelope Glycoprotein (K231C, T257...
# 4905   ACTIVATED TURKEY BETA1 ADRENOCEPTOR WITH BOUND...
# 4911   REFINED CRYSTAL STRUCTURE OF THE INFLUENZA VIR...
# ...                                                  ...
# 17242  Crystal structure of HIV-gp120 core in complex...
# 17253  Crystal structure of the complex between IL-13...
# 17257  Zika specific antibody, ZV-2, bound to ZIKA en...
# 17258  Structure of the Beta2_microglobulin involved ...
# 17270  CRYSTAL STRUCTURE OF HUMAN CD81 LARGE EXTRACEL...
#
#                                                 organism  ... light_ctype  \
# 4880            ENTEROBACTERIA PHAGE 933W; VICUGNA PACOS  ...         NaN
# 4887   INFLUENZA A VIRUS (A/TEXAS/50/2012(H3N2)); HOM...  ...      Lambda
# 4901        HUMAN IMMUNODEFICIENCY VIRUS 1; HOMO SAPIENS  ...       Kappa
# 4905   ESCHERICHIA COLI (STRAIN K12); MELEAGRIS GALLO...  ...         NaN
# 4911                     INFLUENZA A VIRUS; MUS MUSCULUS  ...       Kappa
# ...                                                  ...  ...         ...
# 17242       HUMAN IMMUNODEFICIENCY VIRUS 1; HOMO SAPIENS  ...       Kappa
# 17253                                       HOMO SAPIENS  ...       Kappa
# 17257                           ZIKA VIRUS; MUS MUSCULUS  ...       Kappa
# 17258                  HOMO SAPIENS; CAMELUS DROMEDARIUS  ...         NaN
# 17270                         HOMO SAPIENS; MUS MUSCULUS  ...     unknown
#
#               KD(M)    delta_g Affinity Method Temperature(K)  \
# 4880   9.600000e-09 -10.938139             SPR            NaN
# 4887   4.000000e-08 -10.092596             SPR            NaN
# 4901   8.150000e-07        NaN             SPR            NaN
# 4905   1.400000e-10 -13.443087         Unknown            NaN
# 4911   8.300000e-09 -11.020000           Other         298.15
# ...             ...        ...             ...            ...
# 17242  4.040000e-09 -11.450945             SPR            NaN
# 17253  5.700000e-12 -15.339731             SPR            NaN
# 17257  2.660000e-07  -8.970066             SPR            NaN
# 17258  4.400000e-08 -10.030000             SPR            NaN
# 17270  8.600000e-10 -12.367557             SPR            NaN
#
#       Affinity PubMed ID Ligand Chains Mutations  Ligand Name  Source Data Set
# 4880                 TBD             F       NaN     antibody           SAbDab
# 4887                 TBD          K, L       NaN     antibody           SAbDab
# 4901            17301785          D, C       NaN     antibody           SAbDab
# 4905                 TBD             D       NaN     antibody           SAbDab
# 4911             9692956          H, L       NaN     antibody           SAbDab
# ...                  ...           ...       ...          ...              ...
# 17242                TBD          H, L       NaN     antibody           SAbDab
# 17253                TBD          H, L       NaN     antibody           SAbDab
# 17257                TBD          H, L       NaN     antibody           SAbDab
# 17258           21220305             B       NaN     antibody           SAbDab
# 17270                TBD          H, h       NaN     antibody           SAbDab
#
# [1069 rows x 32 columns]

# %% [markdown]
# # PDB info

# %%
from utils import get_pdb_info

pdbs = set(df['PDB'].values)

for pdb in tqdm.tqdm(pdbs):
    results = get_pdb_info(pdb)
    inds = df[df.PDB==pdb].index
    if results['Resolution']!=None:
        df.loc[inds,'Resolution(Å)'] = results['Resolution'].replace('Å','').strip()
    if results['Method'] != None:
        df.loc[inds,'Structure Method'] = results['Method']
    if results['Release Date'] != None:
        df.loc[inds,'PDB Release Date'] = results['Release Date']
    #这是PDB的PubMed ID, 不是亲和力的PubMed ID
    if results['PubMed ID'] != None:
        df.loc[inds,'PDB PubMed ID'] = results['PubMed ID']
# Out:
# 100%|██████████| 600/600 [17:01<00:00,  1.70s/it]

# %% [markdown]
# # affinity info

# %%
# 调整日期格式
from datetime import datetime
for ind in df.index:
    date_obj = datetime.strptime(df.loc[ind,'Affinity Release Date'], '%m/%d/%y')
    formatted_date = date_obj.strftime('%Y-%m-%d')
    df.loc[ind,'Affinity Release Date'] = formatted_date

# %% [markdown]
# # save

# %%
df.reset_index(drop=True, inplace=True)
df = df.loc[:,[
    'PDB', 'Source Data Set', 'Model', 'Mutations', 'Ligand Chains', 'Receptor Chains', 'Ligand Name', 'Receptor Name', 
    'KD(M)', 'Affinity Method', 'Structure Method', 'Temperature(K)', 'Resolution(Å)', 
    'PDB PubMed ID', 'PDB Release Date', 'Affinity PubMed ID', 'Affinity Release Date', 
]]
df.to_excel( os.path.join(save_dir,'SAbDab.xlsx'), index=True)
display(df)
# Out:
#        PDB Source Data Set  Model  Mutations Ligand Chains Receptor Chains  \
# 0     6FE4          SAbDab      0        NaN             F               A
# 1     5W08          SAbDab      0        NaN          K, L               C
# 2     2NY3          SAbDab      0        NaN          D, C               A
# 3     6H7O          SAbDab      0        NaN             D               B
# 4     1NCA          SAbDab      0        NaN          H, L               N
# ...    ...             ...    ...        ...           ...             ...
# 1064  3IDX          SAbDab      0        NaN          H, L               G
# 1065  4PS4          SAbDab      0        NaN          H, L               A
# 1066  5KVD          SAbDab      0        NaN          H, L               E
# 1067  2X89          SAbDab      0        NaN             B               F
# 1068  6EJM          SAbDab      0        NaN          H, h               B
#
#      Ligand Name                         Receptor Name         KD(M)  \
# 0       antibody          shiga-like toxin 2 subunit b  9.600000e-09
# 1       antibody                     hemagglutinin ha1  4.000000e-08
# 2       antibody           envelope glycoprotein gp120  8.150000e-07
# 3       antibody            beta-1 adrenergic receptor  1.400000e-10
# 4       antibody  influenza a subtype n9 neuraminidase  8.300000e-09
# ...          ...                                   ...           ...
# 1064    antibody                hiv-1 hxbc2 gp120 core  4.040000e-09
# 1065    antibody                        interleukin-13  5.700000e-12
# 1066    antibody                    zika envelope diii  2.660000e-07
# 1067    antibody                  beta-2-microglobulin  4.400000e-08
# 1068    antibody                          cd81 antigen  8.600000e-10
#
#      Affinity Method   Structure Method Temperature(K) Resolution(Å)  \
# 0                SPR  X-RAY DIFFRACTION            NaN          3.00
# 1                SPR  X-RAY DIFFRACTION            NaN          2.60
# 2                SPR  X-RAY DIFFRACTION            NaN          2.00
# 3            Unknown  X-RAY DIFFRACTION            NaN          2.80
# 4              Other  X-RAY DIFFRACTION         298.15          2.50
# ...              ...                ...            ...           ...
# 1064             SPR  X-RAY DIFFRACTION            NaN          2.50
# 1065             SPR  X-RAY DIFFRACTION            NaN          2.80
# 1066             SPR  X-RAY DIFFRACTION            NaN          1.65
# 1067             SPR  X-RAY DIFFRACTION            NaN          2.16
# 1068             SPR  X-RAY DIFFRACTION            NaN          2.15
#
#      PDB PubMed ID PDB Release Date Affinity PubMed ID Affinity Release Date
# 0         29494518       2018-03-07                TBD            2017-12-29
# 1         29343437       2018-02-14                TBD            2017-05-30
# 2         17301785       2007-02-06           17301785            2006-11-20
# 3         31072904       2018-10-17                TBD            2018-07-31
# 4          1381757       1994-01-31            9692956            1992-01-21
# ...            ...              ...                ...                   ...
# 1064      19965434       2009-11-17                TBD            2009-07-22
# 1065      20226193       2014-03-19                TBD            2014-03-06
# 1066      27475895       2016-08-03                TBD            2016-07-14
# 1067      21220305       2011-01-19           21220305            2010-03-07
# 1068      29778602       2018-05-30                TBD            2017-09-22
#
# [1069 rows x 17 columns]
